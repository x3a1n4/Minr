# %%
import csv

with open("blockmodel_avgs.csv", 'r') as file:
    csv_reader = csv.reader(file)
    
    for row in csv_reader:
        print(f"@var bd.add(BlockData(\"{row[0]}\", Colour({row[1]}, {row[2]}, {row[3]}, {row[4]})))")
# Out:
# @var bd.add(BlockData("block_name", Colour(r, g, b, a)))
# @var bd.add(BlockData("acacia_button", Colour(168.0, 90.0, 50.0, 255.0)))
# @var bd.add(BlockData("acacia_door", Colour(165.5, 93.5, 58.5, 172.0)))
# @var bd.add(BlockData("acacia_fence", Colour(168.0, 90.0, 50.0, 255.0)))
# @var bd.add(BlockData("acacia_fence_gate", Colour(168.0, 90.0, 50.0, 255.0)))
# @var bd.add(BlockData("acacia_hanging_sign", Colour(176.0, 93.0, 60.0, 255.0)))
# @var bd.add(BlockData("acacia_leaves", Colour(149.0, 148.0, 148.0, 148.0)))
# @var bd.add(BlockData("acacia_log", Colour(129.5, 93.0, 70.5, 255.0)))
# @var bd.add(BlockData("acacia_planks", Colour(168.0, 90.0, 50.0, 255.0)))
# @var bd.add(BlockData("acacia_pressure_plate", Colour(168.0, 90.0, 50.0, 255.0)))
# @var bd.add(BlockData("acacia_sapling", Colour(119.0, 117.0, 23.0, 130.0)))
# @var bd.add(BlockData("acacia_sign", Colour(168.0, 90.0, 50.0, 255.0)))
# @var bd.add(BlockData("acacia_slab", Colour(168.0, 90.0, 50.0, 255.0)))
# ...

# %%
with open("blockmodel_avgs.csv", 'r') as file:
    csv_reader = csv.reader(file)
    
    for row in csv_reader:
        name = row[0]
        namesp = name.split("_")
        print(f"@var t.add(BlockAlt(\"{"_".join(namesp[1:])}\",  \"{name}\"))")
# Out:
# @var t.add(BlockAlt("name",  "block_name"))
# @var t.add(BlockAlt("button",  "acacia_button"))
# @var t.add(BlockAlt("door",  "acacia_door"))
# @var t.add(BlockAlt("fence",  "acacia_fence"))
# @var t.add(BlockAlt("fence_gate",  "acacia_fence_gate"))
# @var t.add(BlockAlt("hanging_sign",  "acacia_hanging_sign"))
# @var t.add(BlockAlt("leaves",  "acacia_leaves"))
# @var t.add(BlockAlt("log",  "acacia_log"))
# @var t.add(BlockAlt("planks",  "acacia_planks"))
# @var t.add(BlockAlt("pressure_plate",  "acacia_pressure_plate"))
# @var t.add(BlockAlt("sapling",  "acacia_sapling"))
# @var t.add(BlockAlt("sign",  "acacia_sign"))
# @var t.add(BlockAlt("slab",  "acacia_slab"))
# @var t.add(BlockAlt("stairs",  "acacia_stairs"))
# @var t.add(BlockAlt("trapdoor",  "acacia_trapdoor"))
# @var t.add(BlockAlt("wall_hanging_sign",  "acacia_wall_hanging_sign"))
# @var t.add(BlockAlt("wall_sign",  "acacia_wall_sign"))
# @var t.add(BlockAlt("wood",  "acacia_wood"))
# ...
